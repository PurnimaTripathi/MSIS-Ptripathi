# %% [markdown]
# This is a small example of how to wrangle data.

# %%
import pandas as pd
import matplotlib as plt

# %matplotlib inline

# %%
ls -lrt *.csv
# Out:
# -rw-r--r--@ 1 purnima  staff  350610 May  8 14:04 ucdp-prio-acd-4-2016 (1).csv
# -rw-r--r--@ 1 purnima  staff  118484 May  8 14:04 ucdp-nonstate-25-2016.csv
# -rw-r--r--@ 1 purnima  staff  172719 May  8 14:04 ucdp-brd-conf-50-2016.csv
# -rw-r--r--  1 purnima  staff   58872 May  8 14:04 ucdp-onesided-14-2016.csv
# -rw-r--r--  1 purnima  staff   24510 May 13 19:18 MApbattleDeaths.csv
# -rw-r--r--  1 purnima  staff   40317 May 14 14:47 help4.csv
# -rw-r--r--@ 1 purnima  staff   40920 May 15 17:26 COWofwar.csv
# -rw-r--r--  1 purnima  staff   65810 May 20 17:11 MApbattleDeaths_new.csv
# -rw-r--r--  1 purnima  staff    9881 May 22 14:18 Global peace index - Sheet1.csv

# %%
file1 = pd.read_csv('Global peace index - Sheet1.csv')
file1.head()
# Out:
#        country  score_2008  score_2009  score_2010  score_2011  score_2012  \
# 0      Iceland       1.107       1.203       1.212       1.148       1.113
# 1      Denmark       1.238       1.263       1.341       1.289       1.239
# 2      Austria       1.291       1.240       1.290       1.337       1.328
# 3  New Zealand       1.190       1.227       1.188       1.279       1.239
# 4     Portugal       1.385       1.426       1.366       1.453       1.470
#
#    score_2013  score_2014  score_2015  score_2016
# 0       1.162       1.189       1.148       1.192
# 1       1.207       1.193       1.150       1.246
# 2       1.250       1.200       1.198       1.278
# 3       1.237       1.236       1.221       1.287
# 4       1.467       1.425       1.344       1.356

# %%
file2= file1.T
file2.head()
# Out:
#                 0        1        2            3         4               5    \
# country     Iceland  Denmark  Austria  New Zealand  Portugal  Czech Republic
# score_2008    1.107    1.238    1.291         1.19     1.385           1.435
# score_2009    1.203    1.263     1.24        1.227     1.426            1.43
# score_2010    1.212    1.341     1.29        1.188     1.366            1.36
# score_2011    1.148    1.289    1.337        1.279     1.453            1.32
#
#                     6       7      8         9    ...      153    154  \
# country     Switzerland  Canada  Japan  Slovenia  ...    Libya  Sudan
# score_2008        1.234   1.264   1.23      1.37  ...     1.87   3.15
# score_2009        1.349   1.324  1.243     1.343  ...     1.79  3.086
# score_2010        1.424   1.392  1.247     1.358  ...    1.839  3.125
# score_2011        1.421   1.355  1.287     1.358  ...    2.816  3.223
#
#                 155                       156    157      158          159  \
# ...

# %%
file1['mean'] = file1.mean(axis=1)
file1.head()
# Out:
#        country  score_2008  score_2009  score_2010  score_2011  score_2012  \
# 0      Iceland       1.107       1.203       1.212       1.148       1.113
# 1      Denmark       1.238       1.263       1.341       1.289       1.239
# 2      Austria       1.291       1.240       1.290       1.337       1.328
# 3  New Zealand       1.190       1.227       1.188       1.279       1.239
# 4     Portugal       1.385       1.426       1.366       1.453       1.470
#
#    score_2013  score_2014  score_2015  score_2016      mean
# 0       1.162       1.189       1.148       1.192  1.163778
# 1       1.207       1.193       1.150       1.246  1.240667
# 2       1.250       1.200       1.198       1.278  1.268000
# 3       1.237       1.236       1.221       1.287  1.233778
# 4       1.467       1.425       1.344       1.356  1.410222

# %%
GPI= file1.rename(columns={'mean': 'Avg_score'}, inplace=False)
GPI.head()
# Out:
#        country  score_2008  score_2009  score_2010  score_2011  score_2012  \
# 0      Iceland       1.107       1.203       1.212       1.148       1.113
# 1      Denmark       1.238       1.263       1.341       1.289       1.239
# 2      Austria       1.291       1.240       1.290       1.337       1.328
# 3  New Zealand       1.190       1.227       1.188       1.279       1.239
# 4     Portugal       1.385       1.426       1.366       1.453       1.470
#
#    score_2013  score_2014  score_2015  score_2016  Avg_score
# 0       1.162       1.189       1.148       1.192   1.163778
# 1       1.207       1.193       1.150       1.246   1.240667
# 2       1.250       1.200       1.198       1.278   1.268000
# 3       1.237       1.236       1.221       1.287   1.233778
# 4       1.467       1.425       1.344       1.356   1.410222

# %%
GPI.to_csv('GlobalPeaceIndex_new.csv', sep= ';')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ebc71aa0dcfd> in <module>()
# ----> 1 file3 = file3.T
#
# NameError: name 'file3' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1d93562feeaf> in <module>()
# ----> 1 file3.rename(columns={0:'a',1:'b'}, inplace=True)
#       2 file3
#
# NameError: name 'file3' is not defined

# %%
# Out:
#            a        b         c
# 0    35.3846  77.6202   35.3846
# 1    30.0000  84.5433   30.0000
# 2    21.5385  84.9279   21.5385
# 3    17.6923  77.2356   17.6923
# 4    15.3846  66.4663   15.3846
# 5    17.1795  53.0048   17.1795
# 6    16.1538  39.9279   16.1538
# 7    17.4359  29.9279   17.4359
# 8    23.0769  20.3125   23.0769
# 9    27.6923  21.8510   27.6923
# 10   35.1282  22.2356   35.1282
# 11   37.1795  35.3125   37.1795
# 12   37.1795  45.3125   37.1795
# 13   32.3077  51.0817   32.3077
# 14   36.1538  51.0817   36.1538
# 15   38.7179  51.4663   38.7179
# 16   39.7436  42.2356   39.7436
# 17   39.7436  33.7740   39.7436
# 18   40.7692  28.3894   40.7692
# 19   41.2821  24.9279   41.2821
# 20   70.7692  87.6202   70.7692
# 21   61.2821  86.8510   61.2821
# 22   58.4615  74.5433   58.4615
# 23   57.6923  66.0817   57.6923
# 24   57.6923  50.3125   57.6923
# 25   57.6923  43.3894   57.6923
# 26   58.2051  34.9279   58.2051
# 27   60.7692  26.0817   60.7692
# ...

# %%
file_final.plot.scatter(x='c', y='b')

# %%
file_final.to_csv('final.csv', sep=';')

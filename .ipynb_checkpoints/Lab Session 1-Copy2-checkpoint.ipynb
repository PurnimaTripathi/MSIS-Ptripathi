# %% [markdown]
# This is a small example of how to wrangle data.

# %%
import pandas as pd
import matplotlib as plt

# %matplotlib inline

# %%
ls -lrt *.csv
# Out:
# -rw-r--r--@ 1 purnima  staff  350610 May  8 14:04 ucdp-prio-acd-4-2016 (1).csv
# -rw-r--r--@ 1 purnima  staff  118484 May  8 14:04 ucdp-nonstate-25-2016.csv
# -rw-r--r--@ 1 purnima  staff  172719 May  8 14:04 ucdp-brd-conf-50-2016.csv
# -rw-r--r--  1 purnima  staff   58872 May  8 14:04 ucdp-onesided-14-2016.csv
# -rw-r--r--  1 purnima  staff   24510 May 13 19:18 MApbattleDeaths.csv
# -rw-r--r--  1 purnima  staff   40977 May 14 02:36 COWwarlist.csv

# %%
file1 = pd.read_csv('ucdp-brd-conf-50-2016.csv')
file1.head()
# Out:
#    ConflictID    DyadID  Year  LocationInc                      SideA  \
# 0           6       260  1993         Iran         Government of Iran
# 1           6       260  1996         Iran         Government of Iran
# 2           6       260  1990         Iran         Government of Iran
# 3          10  217, 220  1989  Philippines  Government of Philippines
# 4          10  217, 220  1990  Philippines  Government of Philippines
#
#   SideA2nd                                              SideB     SideBID  \
# 0      NaN                                               KDPI        1005
# 1      NaN                                               KDPI        1005
# 2      NaN                                               KDPI        1005
# 3      NaN  CPP, Military faction (forces of Honasan, Aben...  1010, 1011
# 4      NaN  CPP, Military faction (forces of Honasan, Aben...  1010, 1011
#
#   SideB2nd  Incompatibility   ...   TypeOfConflict  BattleLocation  GWNoA  \
# ...

# %%
battleDeaths = pd.read_csv(filepath_or_buffer='ucdp-brd-conf-50-2016.csv', usecols= [2,3,13])
battleDeaths.head(100)
# Out:
#     Year          LocationInc  BdHigh
# 0   1993                 Iran     110
# 1   1996                 Iran      29
# 2   1990                 Iran     335
# 3   1989          Philippines     885
# 4   1990          Philippines    1174
# 5   1991          Philippines    1933
# 6   1992          Philippines     454
# 7   1993          Philippines     114
# 8   1994          Philippines      73
# 9   1995          Philippines      41
# 10  1997          Philippines      32
# 11  1999          Philippines      98
# 12  2000          Philippines     140
# 13  2001          Philippines     299
# 14  2002          Philippines     291
# 15  2003          Philippines     236
# 16  2004          Philippines     344
# 17  2005          Philippines     243
# 18  2006          Philippines    1018
# 19  2007          Philippines    1077
# 20  2008          Philippines     217
# 21  2009          Philippines     400
# 22  2010          Philippines     352
# 23  2011          Philippines     210
# ...

# %%
battleDeaths.to_csv('MApbattleDeaths.csv', sep= ';')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-610c1cf20d35> in <module>()
# ----> 1 MApbattleDeaths.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'
